# %%
import pandas as pd
dataset = pd.read_csv("./dataset/dataset.csv")

# %%
dataset
# Out:
#       question_id                                           question  \
# 0               1                                      RBC contains?
# 1               2                               Fibrosis is due to -
# 2               3  During postmoem no tattoo is visible, but acco...
# 3               4                     Macrodontia is associated with
# 4               5  Ability of stem cells to cross barrier of diff...
# ...           ...                                                ...
# 8995         8996          Factor IX deficiency results in increased
# 8996         8997  In systemic senile amyloidosis there is deposi...
# 8997         8998                            Spongiosis is seen in ?
# 8998         8999                     Stellate Granuloma are seen in
# 8999         9000  Transitional cell carcinoma of bladder is asso...
#
#                       opa                              opb  \
# 0                    Iron                       Folic acid
# ...

# %%
from sklearn.model_selection import train_test_split as tts

X = dataset.drop(columns=['ans'])
y = dataset['ans']
X_train, X_test, y_train ,y_test =  tts(X, y, test_size=0.10, random_state=314657018)
